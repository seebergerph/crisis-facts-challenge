# %% [markdown]
# # Minimum Working Example

# %% [markdown]
# ## Dependencies

# %%
#!pip install numpy
#!pip install pandas
#!pip install scikit-learn
#!pip install nltk
#!pip install stanza
#!pip install tweet-preprocessor
#!pip install wordsegment
#!pip install sentence-transformeres
#!pip install pulp # in our case requires GLPK
#!pip install python-terrier # requires JVM

# %%
import os
import json
import warnings
import numpy as np
import pandas as pd
import pyterrier as pt

# %%
warnings.filterwarnings("ignore")

# %%
os.environ["NLTK_DATA"] = os.path.join(os.getcwd(), ".nltk")
os.environ["STANZA_RESOURCES_DIR"] = os.path.join(os.getcwd(), ".stanza")
os.environ["SENTENCE_TRANSFORMERS_HOME"] = os.path.join(os.getcwd(), ".sbert")
os.environ["TOKENIZERS_PARALLELISM"] = "false"

# %%
# %%capture cap
import src.retrieval as retrieval
import src.reranking as reranking
import src.rescoring as rescoring

# %% [markdown]
# ## Example Datasets

# %%
# wildfire example
queries_file = "data/queries.json"
documents_file = "data/documents.json"

# queries as keywords or "questions" and documents extracted from the web
queries = pd.read_json(queries_file, lines=True)
documents = pd.read_json(documents_file, lines=True)

# %% [markdown]
# ### Queries

# %%
print(f"Number of queries: {len(queries)}")
# Out:
# Number of queries: 5

# %%
queries.head()
# Out:
#        qid                            rerank_query  \
# 0  query-1             How many people are missing
# 1  query-2      What is the fire containment level
# 2  query-3         What roads are blocked / closed
# 3  query-4  What at-risk groups are being impacted
# 4  query-5          What events have been canceled
#
#                                query
# 0                            missing
# 1                        containment
# 2           tree block road closures
# 3  Are there goods needing delivered
# 4                           canceled

# %% [markdown]
# ### Documents

# %%
print(f"Number of documents: {len(documents)}")
# Out:
# Number of documents: 2000

# %%
documents.head()
# Out:
#         docno                                               text source_type
# 0  document-1  .@SDGE turns off power to parts of inland #San...     Twitter
# 1  document-2  #christmas #lilacfire  #PitMad  #DontBeSurpris...     Twitter
# 2  document-3  @realDonaldTrump Switzerland BINGER  🇨🇭 - Spec...     Twitter
# 3  document-4  omg this breaks my heart😰💔I hope everyone’s sa...     Twitter
# 4  document-5  #LilacFire UPDATE: Fire is currently at over 1...     Twitter

# %% [markdown]
# ## Model Initialization

# %% [markdown]
# ### Configuration

# %%
# configuration for the fast retrieval model
retriever_config = retrieval.TerrierRetrieverConfig(
    index_path=".index",
    index_type=3, # just in memory
    meta=["docno", "text", "source_type"],
    meta_lengths=[40, 250, 40],
    wmodel="TF_IDF"
)

# configuraiton for the 'slower' semantic reranking model
reranker_config = reranking.TerrierRerankerConfig(
    model_name_or_path="paraphrase-MiniLM-L6-v2",
    cross_encoder=False,
    max_length=256,
    batch_size=32,
    device="cpu",
    query_col="rerank_query"
)

# %% [markdown]
# ### Modules

# %%
retriever = retrieval.RetrieveModule(model=retrieval.TerrierRetrieverAdapter(retriever_config), top_k=100, threshold=None)
reranker = reranking.RerankModule(model=reranking.TerrierRerankerAdapter(reranker_config), top_k=25, threshold=0.1)

# %%
# Stanza named entity tags
ner_tags = [
    "CARDINAL", "DATE", "EVENT", "FAC", "GPE", 
    "LOC", "MONEY", "ORDINAL", "ORG", "PERCENT", 
    "PRODUCT", "QUANTITY", "TIME"
]

# Extractor for concepts used by ILP
concepts = rescoring.EntityConceptsCreator(
    ner_tags=ner_tags,
    use_gpu=False
)

# ILP optimizer for document selection
ilp = rescoring.ILPModule(
    concepts=concepts,
    max_budget=20,
    min_budget=1,
    solver_path=None # GLPK solver path; None is default setting
)

selector = rescoring.RescoreModule(
    ilp=ilp,
    mmr=None # Do not use Maximal-Marginal Relevance for rescoring
)
# Out:
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.4.0.json:   0%|   …

# %% [markdown]
# ## Run the Pipeline

# %% [markdown]
# ### Stage 1: retrieve with term frequency model

# %%
# %%capture cap
retrieval_results = retriever.retrieve(queries=queries, corpus=documents)
# Out:
# No etc/terrier.properties, using terrier.default.properties for bootstrap configuration.

# %% [markdown]
# ### Stage 2: rerank query-document pairs with contextualized language model

# %%
reranking_results = reranker.rerank(initial_results=retrieval_results)
# Out:
# pt.apply: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:02<00:00,  2.45row/s]

# %% [markdown]
# ### Stage 3: select maximum number of sentences with Integer Linear Programming

# %%
selection_results = selector.rescore(initial_results=reranking_results)

# %% [markdown]
# ## Results

# %%
retrieval_results.drop(columns=["docid", "docno", "qid"])
# Out:
#                                                   text source_type  rank  \
# 0    Missed my frees @ Gaslamp Quarter https://t.co...     Twitter     0
# 1    aww i miss you!! I'll be home soon!!  https://...     Twitter     1
# 2    I missed out on the Awesome cupcakes at the @k...     Twitter     2
# 3    Friday Night 7PM. @thegoodworth @gymstandard d...     Twitter     3
# 4    "0% contained" what the fuck https://t.co/snzd...     Twitter     0
# ..                                                 ...         ...   ...
# 182  Palomar Community College District will be clo...        News     3
# 183  CAL STATE San Marcos cancels classes for the r...     Twitter     4
# 184  @KrisKoivisto All happening at once is rare. G...     Twitter     5
# 185  Los Alamitos Race Course announced that it is ...        News     6
# 186  Los Alamitos Race Course canceled Fridays eigh...        News     7
#
#         score                        rerank_query        query
# 0    1.000000         How many people are missing      missing
# 1    0.717618         How many people are missing      missing
# 2    0.717618         How many people are missing      missing
# 3    0.000000         How many people are missing      missing
# 4    1.000000  What is the fire containment level  containment
# ..        ...                                 ...          ...
# 182  0.513924      What events have been canceled     canceled
# 183  0.513924      What events have been canceled     canceled
# 184  0.451714      What events have been canceled     canceled
# 185  0.451714      What events have been canceled     canceled
# 186  0.000000      What events have been canceled     canceled
#
# [187 rows x 6 columns]

# %%
reranking_results.drop(columns=["docid", "docno", "qid"])
# Out:
#                                                   text source_type     score  \
# 1    aww i miss you!! I'll be home soon!!  https://...     Twitter  1.000000
# 0    Missed my frees @ Gaslamp Quarter https://t.co...     Twitter  0.463001
# 3    Friday Night 7PM. @thegoodworth @gymstandard d...     Twitter  0.354585
# 48   The 30% containment figure means firefighters ...        News  1.000000
# 43   Within 30 min fire grew from 150 acres to 500 ...     Twitter  0.884257
# ..                                                 ...         ...       ...
# 184  @KrisKoivisto All happening at once is rare. G...     Twitter  0.946656
# 185  Los Alamitos Race Course announced that it is ...        News  0.845807
# 186  Los Alamitos Race Course canceled Fridays eigh...        News  0.619060
# 179  my teacher still wont cancel class  https://t....     Twitter  0.565609
# 182  Palomar Community College District will be clo...        News  0.399779
#
#                            rerank_query        query  rank
# 1           How many people are missing      missing     0
# 0           How many people are missing      missing     1
# 3           How many people are missing      missing     2
# 48   What is the fire containment level  containment     0
# 43   What is the fire containment level  containment     1
# ..                                  ...          ...   ...
# 184      What events have been canceled     canceled     2
# 185      What events have been canceled     canceled     3
# 186      What events have been canceled     canceled     4
# 179      What events have been canceled     canceled     5
# 182      What events have been canceled     canceled     6
#
# [85 rows x 6 columns]

# %%
selection_results.sort_values("rank")
# Out:
#             docno       qids                     queries  \
# 1   document-1036  [query-3]  [tree block road closures]
# 60   document-557  [query-3]  [tree block road closures]
# 65   document-627  [query-3]  [tree block road closures]
# 68   document-692  [query-3]  [tree block road closures]
# 34  document-1714  [query-3]  [tree block road closures]
# 62    document-59  [query-2]               [containment]
# 16  document-1321  [query-3]  [tree block road closures]
# 18  document-1352  [query-3]  [tree block road closures]
# 58   document-486  [query-2]               [containment]
# 9   document-1180  [query-3]  [tree block road closures]
# 5    document-111  [query-3]  [tree block road closures]
# 2   document-1076  [query-2]               [containment]
# 26  document-1503  [query-3]  [tree block road closures]
# 78   document-861  [query-2]               [containment]
# 70   document-745  [query-2]               [containment]
# 24  document-1477  [query-5]                  [canceled]
# 10  document-1219  [query-2]               [containment]
# 17  document-1331  [query-2]               [containment]
# 22  document-1427  [query-2]               [containment]
# 8   document-1165  [query-5]                  [canceled]
#
#                           rerank_queries  \
# 1      [What roads are blocked / closed]
# 60     [What roads are blocked / closed]
# 65     [What roads are blocked / closed]
# 68     [What roads are blocked / closed]
# 34     [What roads are blocked / closed]
# 62  [What is the fire containment level]
# 16     [What roads are blocked / closed]
# 18     [What roads are blocked / closed]
# 58  [What is the fire containment level]
# 9      [What roads are blocked / closed]
# 5      [What roads are blocked / closed]
# 2   [What is the fire containment level]
# 26     [What roads are blocked / closed]
# 78  [What is the fire containment level]
# 70  [What is the fire containment level]
# 24      [What events have been canceled]
# 10  [What is the fire containment level]
# 17  [What is the fire containment level]
# 22  [What is the fire containment level]
# 8       [What events have been canceled]
#
#                                                  text                scores  \
# 1   Accident, center lane blocked in #SanDiego on ...  [0.9867403172291037]
# 60  Crash blocking the two left lanes in #SanDiego...  [0.8909598228593092]
# 65  A 3 car crash is blocking the left lane. in #N...  [0.8648129837780589]
# 68  Accident, right lane blocked in #RanchoPenasqu...  [0.8296995408414153]
# 34  Crash blocking the two right lanes in #Mission...  [0.7807792285249736]
# 62  Thomas fire in Ventura and Santa Barbara count...  [0.7254430631822885]
# 16  Closures  The fire, first reported at 11:20 a....  [0.7028954750370993]
# 18  Accident, center lane blocked in #Lakeside on ...  [0.6993499661133604]
# 58  Cal Fire reports 2 structures destroyed  12 ot...  [0.6989716859897075]
# 9    Region south of Camp Pendleton Eastern Fence ...  [0.6845908459211903]
# 5   #BREAKING: #LilacFire Road Closures: Old Hwy 3...  [0.6726382595364854]
# 2   #LilacFire  The fire is now 100-150 acres &amp...  [0.6482714424949892]
# 26   Region south of Reche Road, north of Burma Ro...  [0.6353575573529615]
# 78  UPDATE (December 11, 2017 8:40 a.m.): The Lila...  [0.6326640854578779]
# 70  The blaze, reported about 1:15 p.m. near Los A...  [0.6272989252982865]
# 24  Los Alamitos Race Course canceled Fridays eigh...  [0.6190601026056657]
# 10  #LilacFire burning in North County San Diego i...  [0.5794682161061752]
# 17  Lilac fire in San Diego County  4,100 acres bu...  [0.5597563242168402]
# 22  NBCNews: UPDATE:  #LilacFire in San Diego Coun...  [0.5574910705707394]
# 8   Palomar Community College District will be clo...  [0.3997788428964275]
#
#        score source_type  rank
# 1   1.000000     Twitter     0
# 60  0.836820     Twitter     1
# 65  0.792274     Twitter     2
# 68  0.732451     Twitter     3
# 34  0.649106     Twitter     4
# 62  0.554831        News     5
# 16  0.516417        News     6
# 18  0.510376     Twitter     7
# 58  0.509732     Twitter     8
# 9   0.485231        News     9
# 5   0.464868     Twitter    10
# 2   0.423354     Twitter    11
# 26  0.401353        News    12
# 78  0.396764        News    13
# 70  0.387624        News    14
# 24  0.373587        News    15
# 10  0.306135     Twitter    16
# 17  0.272552        News    17
# 22  0.268693     Twitter    18
# 8   0.000000        News    19
